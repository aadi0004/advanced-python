# %%
# Pandas ===> It is an open source library that is used for handle data manipulations.

# Data structure of pandas
# 1. series ===> It is one dimensional array. it contains only values not column name
# 2. Dataframe ==> It is muldimensional array. it contains values with column name

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
a= pd.Series([1,2,3,4,5])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## DataFrame

# %%
a={
    "Emp_id":[1,2,3,4,5,6,7],
    "name":['sam','shiv','ram','shyam','shiv','pallavi','sam'],
    "Department":['IT','sales','IT','sales','IT','sales','operations'],
    "Working_hours":[8,9,8,7,8,9,9]

}

# %%
type(a)
# Out:
# dict

# %%
df=pd.DataFrame(a)
df
# Out:
#    Emp_id     name  Department  Working_hours
# 0       1      sam          IT              8
# 1       2     shiv       sales              9
# 2       3      ram          IT              8
# 3       4    shyam       sales              7
# 4       5     shiv          IT              8
# 5       6  pallavi       sales              9
# 6       7      sam  operations              9

# %% [markdown]
# ## import and export our dataframe

# %% [markdown]
# ## export

# %%
df.to_csv("C:\\Users\\91937\\OneDrive\\Desktop\\aadi\\emp_info.csv",index=False)   ## index=False is for to remove indexing values

# %% [markdown]
# ## import

# %%
df1=pd.read_csv("C:\\Users\\91937\\OneDrive\\Desktop\\aadi\\emp_info.csv")

# %%
df1
# Out:
#    Emp_id     name  Department  Working_hours
# 0       1      sam          IT              8
# 1       2     shiv       sales              9
# 2       3      ram          IT              8
# 3       4    shyam       sales              7
# 4       5     shiv          IT              8
# 5       6  pallavi       sales              9
# 6       7      sam  operations              9

# %%
df
# Out:
#    Emp_id     name  Department  Working_hours
# 0       1      sam          IT              8
# 1       2     shiv       sales              9
# 2       3      ram          IT              8
# 3       4    shyam       sales              7
# 4       5     shiv          IT              8
# 5       6  pallavi       sales              9
# 6       7      sam  operations              9

# %% [markdown]
# ## head() and tail()

# %%
df.head()
# Out:
#    Emp_id   name Department  Working_hours
# 0       1    sam         IT              8
# 1       2   shiv      sales              9
# 2       3    ram         IT              8
# 3       4  shyam      sales              7
# 4       5   shiv         IT              8

# %%
df.head(2)
# Out:
#    Emp_id  name Department  Working_hours
# 0       1   sam         IT              8
# 1       2  shiv      sales              9

# %%
df.tail()
# Out:
#    Emp_id     name  Department  Working_hours
# 2       3      ram          IT              8
# 3       4    shyam       sales              7
# 4       5     shiv          IT              8
# 5       6  pallavi       sales              9
# 6       7      sam  operations              9

# %%
df.tail(2)
# Out:
#    Emp_id     name  Department  Working_hours
# 5       6  pallavi       sales              9
# 6       7      sam  operations              9

# %% [markdown]
# ## check random index data

# %%
df.sample(3)
# Out:
#    Emp_id     name Department  Working_hours
# 1       2     shiv      sales              9
# 2       3      ram         IT              8
# 5       6  pallavi      sales              9

# %%
df.shape # check shape
# Out:
# (7, 4)

# %%
df.columns  ## check columns name
# Out:
# Index(['Emp_id', 'name', 'Department', 'Working_hours'], dtype='object')

# %% [markdown]
# ## case 1
# you have to update "ram'to 'ravan'

# %%
df['name'][2]='ravan'
# Out:
# C:\Users\91937\AppData\Local\Temp\ipykernel_14348\2383994329.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['name'][2]='ravan'
# C:\Users\91937\AppData\Local\Temp\ipykernel_14348\2383994329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['name'][2]='ravan'

# %%
df
# Out:
#    Emp_id     name  Department  Working_hours
# 0       1      sam          IT              8
# 1       2     shiv       sales              9
# 2       3    ravan          IT              8
# 3       4    shyam       sales              7
# 4       5     shiv          IT              8
# 5       6  pallavi       sales              9
# 6       7      sam  operations              9

# %%
df['Working_hours'][1]=10
# Out:
# C:\Users\91937\AppData\Local\Temp\ipykernel_14348\4155008706.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Working_hours'][1]=10
# C:\Users\91937\AppData\Local\Temp\ipykernel_14348\4155008706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Working_hours'][1]=10

# %%
df
# Out:
#    Emp_id     name  Department  Working_hours
# 0       1      sam          IT              8
# 1       2     shiv       sales             10
# 2       3    ravan          IT              8
# 3       4    shyam       sales              7
# 4       5     shiv          IT              8
# 5       6  pallavi       sales              9
# 6       7      sam  operations              9

# %% [markdown]
# ## check totsl sub_categories frequency of a column

# %%
df['name'].value_counts()
# Out:
# name
# sam        2
# shiv       2
# ravan      1
# shyam      1
# pallavi    1
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# IT            3
# sales         3
# operations    1
# Name: count, dtype: int64

# %%
## check null value

# %%
df.isnull().sum()
# Out:
# Emp_id           0
# name             0
# Department       0
# Working_hours    0
# dtype: int64

# %%
df['name'][3]=None
df['Department'][4]=None
# Out:
# C:\Users\91937\AppData\Local\Temp\ipykernel_14348\1281631395.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['name'][3]=None
# C:\Users\91937\AppData\Local\Temp\ipykernel_14348\1281631395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['name'][3]=None
# C:\Users\91937\AppData\Local\Temp\ipykernel_14348\1281631395.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Department'][4]=None
# C:\Users\91937\AppData\Local\Temp\ipykernel_14348\1281631395.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Department'][4]=None

# %%
df.isnull().sum()
# Out:
# Emp_id           0
# name             1
# Department       1
# Working_hours    0
# dtype: int64

# %% [markdown]
# ## Task 2
# dataframe==> student_information
# columns===> student_id, course_name, course,duration, fees
#
# data import and export
# head(),tail(),sample()
# create missing data , handle missing data
# value_counts()
